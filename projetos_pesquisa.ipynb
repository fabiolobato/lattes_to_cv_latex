# %%
from bs4 import BeautifulSoup
from googletrans import Translator
import pandas as pd
from googletrans import Translator
from googletrans import LANGUAGES

# %%
# Reading data from the xml file
with open('CV_03_04.xml', 'r', encoding='UTF-*') as f:
    data = f.read()

# %%
translator = Translator()

# %% [markdown]
# ## Tag XML
# <PARTICIPACAO-EM-PROJETO SEQUENCIA-FUNCAO-ATIVIDADE="40" FLAG-PERIODO="ATUAL" MES-INICIO="" ANO-INICIO="2021" MES-FIM="" ANO-FIM="" CODIGO-ORGAO="J2HF02000995" NOME-ORGAO="Instituto de Engenharia e Geociências" CODIGO-UNIDADE="" NOME-UNIDADE="">
# <PROJETO-DE-PESQUISA SEQUENCIA-PROJETO="21" ANO-INICIO="2021" ANO-FIM="" NOME-DO-PROJETO="Aprendizado de máquina para otimizar sistema de gestão de relacionamento com os clientes nas mídias sociais" SITUACAO="EM_ANDAMENTO" NATUREZA="PESQUISA" NUMERO-GRADUACAO="10" NUMERO-ESPECIALIZACAO="" NUMERO-MESTRADO-ACADEMICO="" NUMERO-MESTRADO-PROF="3" NUMERO-DOUTORADO="" DESCRICAO-DO-PROJETO="O crescente uso de r" IDENTIFICADOR-PROJETO="" DESCRICAO-DO-PROJETO-INGLES="" NOME-DO-PROJETO-INGLES="" FLAG-POTENCIAL-INOVACAO="SIM" NOME-COORDENADOR-CERTIFICACAO="" DATA-CERTIFICACAO="" NUMERO_TECNICO_NIVEL_MEDIO="">
# <EQUIPE-DO-PROJETO>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Fábio Manoel França Lobato" NOME-PARA-CITACAO="LOBATO, F. M. F.;Lobato, Fábio Manoel Franca;Lobato, Fábio;LOBATO, FABIO;LOBATO, FÁBIO M. F.;LOBATO, FÁBIO M.F.;LOBATO, FÁBIO MANOEL FRANÇA;Lobato, Fábio M. F.;MANOEL FRANÇA LOBATO, FÁBIO" ORDEM-DE-INTEGRACAO="1" FLAG-RESPONSAVEL="SIM" NRO-ID-CNPQ="8320014491229434"/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Marcelino S. da Silva" NOME-PARA-CITACAO="Silva, M. S." ORDEM-DE-INTEGRACAO="2" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Solange Oliveira Rezende" NOME-PARA-CITACAO="REZENDE, S. O." ORDEM-DE-INTEGRACAO="3" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Ricardo Marcondes Marcacini" NOME-PARA-CITACAO="Marcacini, R." ORDEM-DE-INTEGRACAO="4" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Olaf Reinhold" NOME-PARA-CITACAO="REINHOLD, O." ORDEM-DE-INTEGRACAO="5" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Jacob, Antonio Fernando Lavareda" NOME-PARA-CITACAO="Jacob, Antonio Fernando Lavareda" ORDEM-DE-INTEGRACAO="6" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Éfren Lopes de Souza" NOME-PARA-CITACAO="SOUZA, E. L." ORDEM-DE-INTEGRACAO="7" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="NOGUEIRA VIANA, JULIO AUGUSTO" NOME-PARA-CITACAO="NOGUEIRA VIANA, JULIO AUGUSTO" ORDEM-DE-INTEGRACAO="8" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Rafael Geraldeli Rossi" NOME-PARA-CITACAO="ROSSI, R. G." ORDEM-DE-INTEGRACAO="9" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Diego de Azevedo Gomes" NOME-PARA-CITACAO="GOMES, D. A." ORDEM-DE-INTEGRACAO="10" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Michel Marialva Yvano" NOME-PARA-CITACAO="YVANO, M. M." ORDEM-DE-INTEGRACAO="11" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# <INTEGRANTES-DO-PROJETO NOME-COMPLETO="Danielle Costa Carrara Couto" NOME-PARA-CITACAO="COUTO, D. C. C." ORDEM-DE-INTEGRACAO="12" FLAG-RESPONSAVEL="NAO" NRO-ID-CNPQ=""/>
# </EQUIPE-DO-PROJETO>
# <FINANCIADORES-DO-PROJETO>
# <FINANCIADOR-DO-PROJETO SEQUENCIA-FINANCIADOR="2" CODIGO-INSTITUICAO="IZJ800000006" NOME-INSTITUICAO="Fundação Amazônia Paraense de Amparo à Pesquisa" NATUREZA="OUTRO"/>
# <FINANCIADOR-DO-PROJETO SEQUENCIA-FINANCIADOR="1" CODIGO-INSTITUICAO="002200000000" NOME-INSTITUICAO="Conselho Nacional de Desenvolvimento Científico e Tecnológico" NATUREZA="OUTRO"/>
# </FINANCIADORES-DO-PROJETO>
# </PROJETO-DE-PESQUISA>
# </PARTICIPACAO-EM-PROJETO>

# %%
bs_data = BeautifulSoup(data, 'xml')
b_unique = bs_data.find_all('PARTICIPACAO-EM-PROJETO')

"""

"""
#Parte A
ano_inicio = []
ano_fim = []
titulo = []

#Parte B
coordenacao = []


for i in b_unique:

    a = i.find("PROJETO-DE-PESQUISA")
    ano_inicio.append(a.get('ANO-INICIO'))
    ano_fim.append(a.get('ANO-FIM'))
    titulo.append(a.get('NOME-DO-PROJETO'))
    
  
   
    b = i.find("EQUIPE-DO-PROJETO")
    
    r = i.find_all('INTEGRANTES-DO-PROJETO')

    ## aqui só coloco a flag que eu coordeno
    s_autores = ''
    for k in r:
        autor =  k.get('NOME-PARA-CITACAO').lower()
        flag = k.get('FLAG-RESPONSAVEL')
        if('lobato' in autor):
            print(a.get('NOME-DO-PROJETO'), autor, flag)
            coordenacao.append(flag)

     
df = pd.DataFrame()
df['inicio'] = ano_inicio
df['fim'] = ano_fim
df['titulo'] = titulo
df['coordenacao'] = coordenacao
# Out:
# Sistema Inteligente para a Avaliação do Desempenho da Proteção de Sistema de Energia Elétrica via Dados de Pós-Operação lobato, f. m. f.;lobato, fábio manoel franca;lobato, fábio;lobato, fabio;lobato, fábio  m. f.;lobato, fábio m.f.;lobato, fábio manoel frança;lobato, fábio m. f.;manoel frança lobato, fábio NAO
# Programa Nacional de Cooperação Acadêmica - PROCAD lobato, f. m. f.;lobato, fábio manoel franca;lobato, fábio;lobato, fabio;lobato, fábio  m. f.;lobato, fábio m.f.;lobato, fábio manoel frança;lobato, fábio m. f.;manoel frança lobato, fábio NAO
# SMQEE - Sistema de monitoramento da qualidade de energia nas instalações da UHE Coaracy Nunes com análise da contribuição do sistema de aterramento lobato, f. m. f.;lobato, fábio manoel franca;lobato, fábio;lobato, fabio;lobato, fábio  m. f.;lobato, fábio m.f.;lobato, fábio manoel frança;lobato, fábio m. f.;manoel frança lobato, fábio NAO
# ...

# %%
df.head(30)
# Out:
#    inicio   fim                                             titulo
# 0    2008  2010  Sistema Inteligente para a Avaliação do Desemp...
# 1    2010  2013  Programa Nacional de Cooperação Acadêmica - PR...
# 2    2012  2015  SMQEE - Sistema de monitoramento da qualidade ...
# 3    2013  2015  Estudo de estratégias para paralelização de al...
# 4    2014  2019  Research and development of computational inte...
# 5    2011  2014  Planejamento e Análise de Desempenho de Tecnol...
# 6    2015  2020  Avaliação de Impactos da Indução de uma Rede V...
# 7    2014  2018   Rede de pesquisa em genômica populacional humana
# 8    2016  2021  Implantação de uma Fábrica de  Sistemas Comput...
# 9    2019        Social Customer Relationship Management as Spe...
# 10   2020  2022  Impactos psicossociais da pandemia: construind...
# 11   2020        [Bolsa DT/CNPq] Gestão de Relacionamento com C...
# 12   2021        Aprendizado de máquina para otimizar sistema d...
# ...

# %%
df = df.sort_values(by=['ano'], ascending=False)

# %%
df.columns
# Out:
# Index(['natureza', 'titulo', 'ano', 'promotora', 'local', 'cidade', 'autores'], dtype='object')

# %%
df_comite = df.loc[df['natureza']=='ORGANIZACAO']
len(df_comite)
# Out:
# 22

# %%
df_comite = df_comite.sort_values(by='ano', ascending=False)

# %%
df_comite.head(3)
# Out:
#        natureza                                             titulo   ano  \
# 21  ORGANIZACAO  II Seminário de Pesquisa e Desenvolvimento de ...  2023
# 20  ORGANIZACAO                        IV Workshop Social CRM 2022  2022
# 19  ORGANIZACAO  7th International Workshop on Integrated Socia...  2022
#
#                      promotora                                       local  \
# 21   ToadaLab/TJMA e PECS/UEMA  Laboratório de Inovação do TJMA: Toada-Lab
# 20  Social CRM Research Center
# 19                IEEE/WIC/ACM                                      Canada
#
#            cidade                                            autores
# 21   São Luís, MA  Jacob, Antonio Fernando Lavareda; Santana, E. ...
# 20          Belém  Alt, R.; Reinhold, O.; Nogueira Viana, Julio A...
# 19  Niagara Falls  Alt, Rainer; Reinhold, O.; Lobato, Fábio Manoe...

# %%
#[FASE]: International Conference on Fundamental Approaches to Software Engineering 2023. Role: Artifact Evaluation Committee Chair
#Index(['natureza', 'titulo', 'ano', 'promotora', 'local', 'cidade', 'autores'], dtype='object')

for index, row in df_comite.iterrows():


        
    print('\item', '\\textbf{SIGLA}',  row.titulo, '('+row.ano+'),', row.promotora+',', row.cidade+', ', ' Role: Organizing Committee')
# Out:
# \item \textbf{SIGLA} II Seminário de Pesquisa e Desenvolvimento de Inovação Toada Lab/TJMA e UEMA (2023), ToadaLab/TJMA e PECS/UEMA, São Luís, MA,   Role: Organizing Committee
# \item \textbf{SIGLA} IV Workshop Social CRM 2022 (2022), Social CRM Research Center, Belém,   Role: Organizing Committee
# \item \textbf{SIGLA} 7th International Workshop on Integrated Social CRM (i (2022), IEEE/WIC/ACM, Niagara Falls,   Role: Organizing Committee
# \item \textbf{SIGLA} Social CRM Workshop 2021 (2021), Social CRM Research Center, Online,   Role: Organizing Committee
# \item \textbf{SIGLA} X SEMINÁRIO DE INICIAÇÃO CIENTÍFICA - UFOPA (2021), Universidade Federal do Oeste do Pará, ,   Role: Organizing Committee
# \item \textbf{SIGLA} X Brazilian Workshop on Social Network Analysis and Mining (BraSNAM 2021) (2021), CSBC, Online,   Role: Organizing Committee
# ...
